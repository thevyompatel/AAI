# %% [markdown]
# - VYOM PATEL
# - 202307020084
# - BTECH CSE AIML SEM 7
# - AAI LAB EXPERIMENT 1

# %%
from google import genai

client = genai.Client(api_key="AQ.Ab8RN6JpTQ5v-PoDtrfDdLB1Lf7h6OTqts3p13ac_I1e-RqCvw")

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="What is Agentic AI?"
)

print(response.text)
# Out:
# **Agentic AI** refers to a type of artificial intelligence system that is designed to act autonomously, often in complex and dynamic environments, to achieve a specific goal or set of goals. The key concept here is "agency" – the ability to initiate actions, make decisions, and interact with its environment without constant human intervention.
#
# Think of it less like a simple chatbot that just responds to your queries, and more like a proactive assistant that can *do things* to accomplish a task for you.
#
# ### Key Characteristics of Agentic AI:
#
# 1.  **Goal-Oriented:** Agentic AI systems are given a high-level objective (e.g., "Plan my trip to Japan," "Debug this code," "Research the market for electric vehicles"). They then work to achieve this objective.
# 2.  **Autonomy:** Once given a goal, the agent can plan its own steps, execute actions, and adapt its strategy without continuous human commands for each step.
# ...

# %%
from google import genai
client = genai.Client(api_key = "AQ.Ab8RN6JpTQ5v-PoDtrfDdLB1Lf7h6OTqts3p13ac_I1e-RqCvw")
goal = input ("Enter your goal :")
prompt = f"""
You are an AI Agent
Your task is to achieve the following goal.
Goal:
{goal}
Think steo by step.
Return
1.Objective
2.Required Information
3.Action Plan
4.Expected Result
"""
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=prompt
)

print(response.text)
# Out:
# Enter your goal :Plan a one-day AI workshop for engineering students.
# Here's a plan for a one-day AI workshop for engineering students:
#
# ---
#
# ### One-Day AI Workshop for Engineering Students
#
# **1. Objective**
#
# The primary objective of this one-day workshop is to provide engineering students with a foundational understanding of Artificial Intelligence (AI), Machine Learning (ML), and Deep Learning (DL), their core concepts, practical applications relevant to various engineering disciplines, and an initial hands-on experience to spark further interest and self-learning.
#
# Specifically, students will be able to:
# *   Understand the basic definitions and distinctions between AI, ML, and DL.
# *   Identify key AI/ML concepts such as data, features, models, training, and evaluation.
# *   Recognize various applications of AI in engineering fields (e.g., predictive maintenance, robotics, control systems, image processing).
# ...

# %%
from google import genai
client = genai.Client(api_key = "AQ.Ab8RN6JpTQ5v-PoDtrfDdLB1Lf7h6OTqts3p13ac_I1e-RqCvw")
def ai_agent(goal):
  prompt=f"""
  You are an intelligent planning agent.
  Goal:
  {goal}
  Think step by step.
  """
  response = client.models.generate_content(
      model="gemini-2.5-flash",
      contents=prompt
  )
  return response.text
goal = input("Goal:")
answer = ai_agent(goal)
print(answer)
# Out:
# Goal:Openai vs Anthropic
# As an intelligent planning agent, let's break down the OpenAI vs. Anthropic landscape step-by-step, analyzing their core philosophies, products, strategies, and key differentiators.
#
# ---
#
# ## OpenAI vs. Anthropic: A Step-by-Step Comparison
#
# ### Step 1: Core Mission & Founding Philosophy
#
# **OpenAI:**
# *   **Mission:** To ensure that artificial general intelligence (AGI) benefits all of humanity. Initially founded as a non-profit, it restructured to a "capped-profit" model to raise the vast capital needed for AGI development.
# *   **Philosophy:** Emphasizes rapid iteration, broad deployment, and direct user feedback to improve safety and capabilities. The belief is that exposing AI to the world responsibly is key to understanding and aligning it. "Democratizing" access to advanced AI.
# *   **Key Figures:** Sam Altman (CEO), Greg Brockman (President), Ilya Sutskever (Chief Scientist).
#
# **Anthropic:**
# ...

# %%
from google import genai

client = genai.Client(api_key="AQ.Ab8RN6JpTQ5v-PoDtrfDdLB1Lf7h6OTqts3p13ac_I1e-RqCvw")

normal = "How do I prepare for Python?"

agent = """
You are an AI Study Planner.

Prepare a 7-day roadmap.

Suggest resources.

Suggest practice.

Estimate daily study hours.

Mention checkpoints.
"""

print("----------- Normal Prompt -----------")

response1 = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=normal
)

print(response1.text)

print("\n----------- Agent Prompt -----------")

response2 = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=agent
)

print(response2.text)
# Out:
# ----------- Normal Prompt -----------
# Preparing for Python is an exciting journey! Python is a fantastic language for beginners due to its readability and versatility. Here's a comprehensive guide to help you get started:
#
# ## Phase 1: Before You Code (Setup & Mindset)
#
# 1.  **Understand What Python Is & Why It's Popular:**
#     *   Python is a high-level, interpreted programming language.
#     *   It's known for its readability (syntax similar to English).
#     *   It's incredibly versatile: web development, data science, machine learning, automation, scripting, game development, desktop apps, etc.
#     *   Knowing its broad applications can motivate you!
#
# 2.  **Install Python:**
#     *   Go to the official Python website: [python.org/downloads](https://www.python.org/downloads/)
#     *   Download the latest stable version (e.g., Python 3.x.x).
# ...

# %%
from google import genai

client = genai.Client(api_key="AQ.Ab8RN6JpTQ5v-PoDtrfDdLB1Lf7h6OTqts3p13ac_I1e-RqCvw")

roles = {
    1: "Student Advisor",
    2: "Career Coach",
    3: "Travel Planner",
    4: "Research Assistant"
}

print("Choose Agent")
print("1. Student Advisor")
print("2. Career Coach")
print("3. Travel Planner")
print("4. Research Assistant")

choice = int(input("Enter choice: "))

goal = input("Enter Goal: ")

role = roles.get(choice, "General AI Assistant")

prompt = f"""
You are a {role}.

Goal:
{goal}

Think step by step.

Provide

1. Objective

2. Required Information

3. Action Plan

4. Expected Result
"""

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=prompt
)

print("\nAgent Response\n")

print(response.text)
# Out:
# Choose Agent
# 1. Student Advisor
# 2. Career Coach
# 3. Travel Planner
# 4. Research Assistant
# Enter choice: 2
# Enter Goal: Become an AI Engineer
#
# Agent Response
#
# Hello! That's an excellent and ambitious goal. Becoming an AI Engineer is a highly sought-after path, combining the rigour of software engineering with the cutting-edge of machine learning and artificial intelligence.
#
# Let's break down your journey step-by-step.
#
# ---
#
# ### 1. Objective
#
# To successfully transition into or secure an entry-level/junior AI Engineer role within the next 12-18 months, by developing a robust skill set in core AI/ML principles, advanced programming, software engineering best practices, MLOps, and cloud deployment, culminating in a compelling portfolio of end-to-end AI projects and a strong professional network.
#
# ---
#
# ### 2. Required Information (From You - The Aspiring AI Engineer)
#
# ...
